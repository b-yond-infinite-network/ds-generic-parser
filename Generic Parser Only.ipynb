# %%
import pandas as pd
import os
import subprocess
import json
import numpy as np
from multiprocessing import Pool
import multiprocessing
import pickle
import Model_ETL
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.metrics import silhouette_samples, silhouette_score
pd.set_option('display.max_columns', None)

# %%
pcap_folder='/dsfiles/joseph_folder/dry_run'
#pcap_folder='/dsfiles/joseph_folder/JSON_DTAG'

pickle.dump( pcap_folder, open( "pcap_folder.p", "wb" ) )
import PCAP_Generic_Parser_Helper

# %%
num_processors = multiprocessing.cpu_count()

# %%
# Fetch ALL files that end in PCAP
pcap_file_names = [ x for x in os.listdir(pcap_folder) if x.endswith("pcap") ]

# %%
len(pcap_file_names)
# Out:
# 48

# %%
# Create raw file names of pcap files without extension ".pcap"
files=[]
for file in pcap_file_names:
    files.append(file.split('.pcap')[0])

# %%
# Parallelize PCAP Conversion to Json
num_processors = multiprocessing.cpu_count()
p=Pool(processes = num_processors)
#pcaps_list = p.map(PCAP_Generic_Parser_Helper.convert_pcap,files)

# %%
# Fetch ALL files that end in json
json_files = [ x for x in os.listdir(pcap_folder) if x.endswith("json") ]

# %%
len(json_files)
# Out:
# 187

# %% [markdown]
# # Sip Parser

# %%
# Parallelize data ingestion and conversion into dataframe
p=Pool(processes = num_processors)
sip_dataframes_output = p.map(PCAP_Generic_Parser_Helper.read_parse_generic,json_files)

# %%
# Get output from original parser and concatenate both
sip_df_out_final=pd.DataFrame(data=sip_dataframes_output)
sip_df_out_final.fillna("*", inplace = True) 
sip_df_out_final=sip_df_out_final.set_index(sip_df_out_final.columns[0])
sip_df_out_final.index.names = ['pcap']
sip_df_out_final=sip_df_out_final.add_prefix('sip ')

# %%
sip_df_out_final.to_csv('dry_run_sip.csv')
sip_df_out_final
# Out:
#                                                                   sip 1  \
# pcap
# PASSED-3PTY_003a-20200716_103917_20200716_1040_...  UE-INVITE-P-CSCF02A
# FAILED-FUNC_ICBVBL_001-20200701_082101_20200701...  UE-INVITE-P-CSCF02A
# FAILED-FUNC_ICBVBL_001-20200625_091222_20200625...  UE-INVITE-P-CSCF02A
# FAILED-FUNC_ICBVBL_001-20200625_101931_20200625...  UE-INVITE-P-CSCF02A
# 1eFTS8reAN_timothy.vogel@verizonwireless.com_Sc...   UE-REGISTER-P-CSCF
# ...                                                                 ...
# PASSED-3PTY_001a-20200615_092358__RCA_PoC_12_15...  UE-INVITE-P-CSCF02A
# Hy3vANpPwn_timothy.vogel@verizonwireless.com_Sc...   UE-REGISTER-P-CSCF
# PASSED-3PTY_003a-20200626_091744_20200626_0920_...  UE-INVITE-P-CSCF02A
# PASSED-3PTY_002a-20200626_091744_20200626_0920_...  UE-INVITE-P-CSCF02A
# timothy.vogel@verizonwireless.com_Scheduled_PS9...             -200-MSC
#
#                                                                  sip 2  \
# pcap
# ...

# %% [markdown]
# # GTPv2 Parser

# %%
# Get all possible gtpv2 causes
p=multiprocessing.Pool(processes = num_processors)
protocols_list_from_tshark = p.map(PCAP_Generic_Parser_Helper.tshark_aggregate_gtpcause,pcap_file_names)
# Split each protocol to a new row
values = set()
for x in protocols_list_from_tshark:
    values.update(x)
try:
    values.remove('')
except KeyError as e:
    pass
gtp_causes=list(values)
pickle.dump( gtp_causes, open( "gtpcauses.p", "wb" ) )

# %%
# Parallelize data ingestion and conversion into dataframe
p=Pool(processes = num_processors)
gtp_dataframes_output = p.map(PCAP_Generic_Parser_Helper.read_parse_gtp,json_files)

# %%
# Get output from original parser and concatenate both
gtp_df_out_final=pd.DataFrame(data=gtp_dataframes_output)
gtp_df_out_final.fillna("*", inplace = True) 
#df_out_final['pcap']=json_files
gtp_df_out_final=gtp_df_out_final.set_index(gtp_df_out_final.columns[0])
gtp_df_out_final.index.names = ['pcap']
gtp_df_out_final = gtp_df_out_final.rename(columns={1: 'n Requests', 2: 'n Responses', 3: 'n unanswered requests'})
gtp_df_out_final=gtp_df_out_final.add_prefix('gtpv2 ')

for i in range(0,len(gtp_causes)):
    gtp_df_out_final = gtp_df_out_final.rename(columns={'gtpv2 '+str(i+4): 'gtpv2 cause = '+str(gtp_causes[i])})

# %%
gtp_df_out_final
# Out:
#                                                    gtpv2 n Requests  \
# pcap
# Nokia_Ocs_77_PCRF_IMS_Internet_APN_Attach_MBP1_...                5
# TS103_5GM_ABU_4G_Throttle_TC003_Before_Threshol...                3
# Basic_5G_Combo_NonCombo_TC004_NonCombo_Attach_D...                4
# TS102_Ppd_UNL_5G_Concession_Sub_TC009_4G_Deprio...                2
# Basic_5G_Combo_NonCombo_TC003_Combo_Attach_SMS_...                3
# ...                                                             ...
# TS102_Ppd_UNL_5G_Concession_Sub_TC009_4G_Deprio...               11
# Basic_5G_Combo_NonCombo_TC001_Combo_Attach_Data...                7
# Basic_5G_Combo_NonCombo_TC001_Combo_Attach_Data...                2
# Basic_5G_Combo_NonCombo_TC002_Combo_Attach_Voic...               14
# TS104_eAMBR_PCRF_TC002_PRA_4G_to_5G_e8981489-5e...               12
#
#                                                    gtpv2 n Responses  \
# pcap
# ...

# %%
gtp_df_out_final.to_csv('GTP_Parser_5G_2500_pcaps.csv')

# %% [markdown]
# # Diameter Parser

# %%
# Get all possible diameter result codes
p=multiprocessing.Pool(processes = num_processors)
protocols_list_from_tshark = p.map(PCAP_Generic_Parser_Helper.tshark_aggregate_diameterresultcode,pcap_file_names)
# Split each protocol to a new row
values = set()
for x in protocols_list_from_tshark:
    values.update(x)
try:
    values.remove('')
except KeyError as e:
    pass
diameter_result_codes=list(values)
import pickle
pickle.dump( diameter_result_codes, open( "diameter_result_codes.p", "wb" ) )

# %%
# Parallelize data ingestion and conversion into dataframe
p=Pool(processes = num_processors)
diameter_dataframes_output = p.map(PCAP_Generic_Parser_Helper.read_parse_diameter,json_files)

# %%
# Get output from original parser and concatenate both
diameter_df_out_final=pd.DataFrame(data=diameter_dataframes_output)
diameter_df_out_final.fillna("*", inplace = True) 
#df_out_final['pcap']=json_files
diameter_df_out_final=diameter_df_out_final.set_index(diameter_df_out_final.columns[0])
diameter_df_out_final.index.names = ['pcap']
diameter_df_out_final = diameter_df_out_final.rename(columns={1: 'n Requests', 2: 'n Responses', 3: 'n unanswered requests'})
diameter_df_out_final=diameter_df_out_final.add_prefix('diameter ')

for i in range(0,len(diameter_result_codes)):
    diameter_df_out_final = diameter_df_out_final.rename(columns={'diameter '+str(i+4): 'diameter result code = '+str(diameter_result_codes[i])})

# %%
diameter_df_out_final
# Out:
#                                                    diameter n Requests  \
# pcap
# Nokia_Ocs_77_PCRF_IMS_Internet_APN_Attach_MBP1_...                   0
# TS103_5GM_ABU_4G_Throttle_TC003_Before_Threshol...                   0
# Basic_5G_Combo_NonCombo_TC004_NonCombo_Attach_D...                   0
# TS102_Ppd_UNL_5G_Concession_Sub_TC009_4G_Deprio...                   0
# Basic_5G_Combo_NonCombo_TC003_Combo_Attach_SMS_...                   0
# ...                                                                ...
# TS102_Ppd_UNL_5G_Concession_Sub_TC009_4G_Deprio...                   0
# Basic_5G_Combo_NonCombo_TC001_Combo_Attach_Data...                   0
# Basic_5G_Combo_NonCombo_TC001_Combo_Attach_Data...                   0
# Basic_5G_Combo_NonCombo_TC002_Combo_Attach_Voic...                   0
# TS104_eAMBR_PCRF_TC002_PRA_4G_to_5G_e8981489-5e...                   0
#
#                                                    diameter n Responses  \
# pcap
# ...

# %%
diameter_df_out_final.to_csv('diameter_Parser_5G_2500-pcaps.csv')

# %% [markdown]
# # Merge sip, gtpv2, and diameter Parser Outputs

# %%
pd.concat([diameter_df_out_final, gtp_df_out_final, sip_df_out_final], keys=['pcap', 'pcap', 'pcap'], axis=1).to_csv('generic_parser_all_protocols.csv')

# %%
pd.merge(gtp_df_out_final, sip_df_out_final, on='pcap').to_csv('gtp_sip_parser_2500_pcaps.csv')

# %%
#pd.concat([gtp_df_out_final, sip_df_out_final], keys=['pcap', 'pcap'], axis=1)
